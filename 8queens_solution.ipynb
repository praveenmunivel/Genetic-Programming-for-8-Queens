# %%
import numpy as np
import sys



nQueens = 8
STOP_CTR = 28
MUTATE = 0.000001
MUTATE_FLAG = True
MAX_ITER = 100000
POPULATION = None

class BoardPosition:
	def __init__(self):
		self.sequence = None
		self.fitness = None
		self.survival = None
	def setSequence(self, val):
		self.sequence = val
	def setFitness(self, fitness):
		self.fitness = fitness
	def setSurvival(self, val):
		self.survival = val
	def getAttr(self):
		return {'sequence':sequence, 'fitness':fitness, 'survival':survival}

def fitness(chromosome = None):
	clashes = 0;
	row_col_clashes = abs(len(chromosome) - len(np.unique(chromosome)))
	clashes += row_col_clashes

	# calculate diagonal clashes
	for i in range(len(chromosome)):
		for j in range(len(chromosome)):
			if ( i != j):
				dx = abs(i-j)
				dy = abs(chromosome[i] - chromosome[j])
				if(dx == dy):
					clashes += 1


	return 28 - clashes	


def generateChromosome():
	global nQueens
	init_distribution = np.arange(nQueens)
	np.random.shuffle(init_distribution)
	return init_distribution

def generatePopulation(population_size = 100):
	global POPULATION

	POPULATION = population_size

	population = [BoardPosition() for i in range(population_size)]
	for i in range(population_size):
		population[i].setSequence(generateChromosome())
		population[i].setFitness(fitness(population[i].sequence))

	return population


def getParent():
	globals()	
	parent1, parent2 = None, None
	summation_fitness = np.sum([x.fitness for x in population])
	for each in population:
		each.survival = each.fitness/(summation_fitness*1.0)

	while True:
		parent1_random = np.random.rand()
		parent1_rn = [x for x in population if x.survival <= parent1_random]
		try:
			parent1 = parent1_rn[0]
			break
		except:
			pass

	while True:
		parent2_random = np.random.rand()
		parent2_rn = [x for x in population if x.survival <= parent2_random]
		try:
			t = np.random.randint(len(parent2_rn))
			parent2 = parent2_rn[t]
			if parent2 != parent1:
				break
			else:
				print ("equal parents")
				continue
		except:
			print ("exception")
			continue

	if parent1 is not None and parent2 is not None:
		return parent1, parent2
	else:
		sys.exit(-1)

def reproduce_crossover(parent1, parent2):
	globals()
	n = len(parent1.sequence)
	c = np.random.randint(n, size=1)
	child = BoardPosition()
	child.sequence = []
	child.sequence.extend(parent1.sequence[0:c])
	child.sequence.extend(parent2.sequence[c:])
	child.setFitness(fitness(child.sequence))
	return child


def mutate(child):
	if child.survival < MUTATE:
		c = np.random.randint(8)
		child.sequence[c] = np.random.randint(8)
	return child

def GA(iteration):
	print (" #"*10 ,"Executing Genetic  generation : ", iteration , " #"*10)
	globals()
	newpopulation = []
	for i in range(len(population)):
		parent1, parent2 = getParent()
		# print "Parents generated : ", parent1, parent2

		child = reproduce_crossover(parent1, parent2)

		if(MUTATE_FLAG):
			child = mutate(child)

		newpopulation.append(child)
	return newpopulation


def stop():
	globals()
	fitnessvals = [pos.fitness for pos in population]
	if STOP_CTR in fitnessvals:
		return True
	if MAX_ITER == iteration:
		return True
	return False



population = generatePopulation(1000)

print ("POPULATION size : ", list(population))

iteration = 0;
while not stop():
	# keep iteratin till  you find the best position
	population = GA(iteration)
	iteration +=1 
lt=[]
for i in population:
    if(i.fitness==28):
        lt=i.sequence
        break
print(lt)
# Out:
# POPULATION size :  [<__main__.BoardPosition object at 0x00000228AAF1F548>, <__main__.BoardPosition object at 0x00000228AAE266C8>, <__main__.BoardPosition object at 0x00000228AAE26C48>, <__main__.BoardPosition object at 0x00000228BA372EC8>, <__main__.BoardPosition object at 0x00000228BA372588>, <__main__.BoardPosition object at 0x00000228BA3723C8>, <__main__.BoardPosition object at 0x00000228BA372F88>, <__main__.BoardPosition object at 0x00000228BA372F48>, <__main__.BoardPosition object at 0x00000228BA372F08>, <__main__.BoardPosition object at 0x00000228BA372708>, <__main__.BoardPosition object at 0x00000228BA372E88>, <__main__.BoardPosition object at 0x00000228BA372E48>, <__main__.BoardPosition object at 0x00000228BA372E08>, <__main__.BoardPosition object at 0x00000228BA372DC8>, <__main__.BoardPosition object at 0x00000228BA372D88>, <__main__.BoardPosition object at 0x00000228BA372D48>, <__main__.BoardPosition object at 0x00000228BA372CC8>, <__main__.BoardPosition object at 0x00000228BA372C48>, <__main__.BoardPosition object at 0x00000228BA372A48>, <__main__.BoardPosition object at 0x00000228BA372A08>, <__main__.BoardPosition object at 0x00000228BA3729C8>, <__main__.BoardPosition object at 0x00000228BA372988>, <__main__.BoardPosition object at 0x00000228BA372948>, <__main__.BoardPosition object at 0x00000228BA3728C8>, <__main__.BoardPosition object at 0x00000228BA372888>, <__main__.BoardPosition object at 0x00000228BA372848>, <__main__.BoardPosition object at 0x00000228BA372808>, <__main__.BoardPosition object at 0x00000228BA3727C8>, <__main__.BoardPosition object at 0x00000228BA372788>, <__main__.BoardPosition object at 0x00000228BA372748>, <__main__.BoardPosition object at 0x00000228BA3726C8>, <__main__.BoardPosition object at 0x00000228BA372688>, <__main__.BoardPosition object at 0x00000228BA372648>, <__main__.BoardPosition object at 0x00000228BA372608>, <__main__.BoardPosition object at 0x00000228BA3725C8>, <__main__.BoardPosition object at 0x00000228BA372548>, <__main__.BoardPosition object at 0x00000228BA372508>, <__main__.BoardPosition object at 0x00000228BA372488>, <__main__.BoardPosition object at 0x00000228BA372448>, <__main__.BoardPosition object at 0x00000228BA372408>, <__main__.BoardPosition object at 0x00000228BA372348>, <__main__.BoardPosition object at 0x00000228BA372308>, <__main__.BoardPosition object at 0x00000228BA372288>, <__main__.BoardPosition object at 0x00000228BA372248>, <__main__.BoardPosition object at 0x00000228BA372208>, <__main__.BoardPosition object at 0x00000228BA3721C8>, <__main__.BoardPosition object at 0x00000228BA372188>, <__main__.BoardPosition object at 0x00000228BA372108>, <__main__.BoardPosition object at 0x00000228BA3720C8>, <__main__.BoardPosition object at 0x00000228BA372048>, <__main__.BoardPosition object at 0x00000228BA35CB48>, <__main__.BoardPosition object at 0x00000228BA35CC48>, <__main__.BoardPosition object at 0x00000228BA35CD48>, <__main__.BoardPosition object at 0x00000228BA35CA48>, <__main__.BoardPosition object at 0x00000228BA35CDC8>, <__main__.BoardPosition object at 0x00000228BA35CB88>, <__main__.BoardPosition object at 0x00000228BA35CD08>, <__main__.BoardPosition object at 0x00000228BA35CC08>, <__main__.BoardPosition object at 0x00000228BA35CC88>, <__main__.BoardPosition object at 0x00000228BA35CB08>, <__main__.BoardPosition object at 0x00000228BA35C988>, <__main__.BoardPosition object at 0x00000228BA35CF88>, <__main__.BoardPosition object at 0x00000228BA35CAC8>, <__main__.BoardPosition object at 0x00000228BA35CFC8>, <__main__.BoardPosition object at 0x00000228BA35CCC8>, <__main__.BoardPosition object at 0x00000228BA35CE48>, <__main__.BoardPosition object at 0x00000228BA35CA08>, <__main__.BoardPosition object at 0x00000228BA35CBC8>, <__main__.BoardPosition object at 0x00000228BA35CE88>, <__main__.BoardPosition object at 0x00000228BA35CF48>, <__main__.BoardPosition object at 0x00000228BA35CEC8>, <__main__.BoardPosition object at 0x00000228BA35CF08>, <__main__.BoardPosit ...
# [3 7 0 4 6 1 5 2]
